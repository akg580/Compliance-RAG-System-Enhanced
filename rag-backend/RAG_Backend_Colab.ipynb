# %% [markdown]
# # RAG Backend - Working Version
# Run all cells in order. No Windows DLL issues!

# %%
# 1. Install dependencies
# !pip install -q fastapi uvicorn pydantic pydantic-settings
# !pip install -q langchain chromadb sentence-transformers
# !pip install -q pypdf openai python-multipart
# !pip install -q nest-asyncio pyngrok
print('✅ Dependencies installed')

# %%
# 2. Set OpenAI API Key
import os
from getpass import getpass
os.environ['OPENAI_API_KEY'] = getpass('Enter OpenAI API Key: ')
print('✅ API key set')

# %%
# 3. Create all Python files
import os
os.makedirs('models', exist_ok=True)
os.makedirs('services', exist_ok=True)
os.makedirs('config', exist_ok=True)
os.makedirs('uploads', exist_ok=True)

# Write all the code files here...
# (I'll provide the complete code below)
print('✅ Files created')

# %%
# 4. Start FastAPI server
import nest_asyncio
nest_asyncio.apply()

# !python main.py &
print('✅ Server started on http://localhost:8000')
